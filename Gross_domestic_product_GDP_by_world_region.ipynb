# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

# URL of the webpage
url = 'https://ourworldindata.org/grapher/gdp-world-regions-stacked-area?tab=table'
# Set up Chrome webdriver options
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
# Add additional options as needed

# Initialize Chrome webdriver
driver = webdriver.Chrome(options=options)

# Open the webpage
driver.get(url)

# Find the first table element
first_table = driver.find_element(By.TAG_NAME, 'table')

# Extract the table data
table_data = []
rows = first_table.find_elements(By.TAG_NAME, 'tr')
for row in rows:
    # Extract text from each cell in the row
    cells = row.find_elements(By.TAG_NAME, 'td')
    row_data = [cell.text.strip() for cell in cells]
    # Append row data to table_data if not empty
    if row_data:
        table_data.append(row_data)

# Close the webdriver
driver.quit()

# Add an empty row at the beginning of the table data
table_data.insert(0, [''] * len(table_data[0]))

# Convert the table data into a pandas DataFrame
df = pd.DataFrame(table_data[1:], columns=table_data[0])  # Assuming the first row contains column headers

# Set the header as "Gross domestic product (GDP) by world region"
df.columns = ['Gross domestic product (GDP) by world region 2018'] + list(df.columns[1:])

# Print the DataFrame
print(df)
# Out:
#   Gross domestic product (GDP) by world region 2018
# 0                                   East Asia (MPD)    $26,432,971,000,000
# 1                              Eastern Europe (MPD)     $8,404,875,000,000
# 2                               Latin America (MPD)     $8,733,149,600,000
# 3                                 Middle East (MPD)     $9,842,624,000,000
# 4                   South and South-East Asia (MPD)    $18,559,032,000,000
# 5                          Sub-Saharan Africa (MPD)     $3,701,549,600,000
# 6                              Western Europe (MPD)    $16,736,345,000,000
# 7                           Western offshoots (MPD)    $21,219,620,000,000

# %%
df
# Out:
#   Gross domestic product (GDP) by world region 2018
# 0                                   East Asia (MPD)    $26,432,971,000,000
# 1                              Eastern Europe (MPD)     $8,404,875,000,000
# 2                               Latin America (MPD)     $8,733,149,600,000
# 3                                 Middle East (MPD)     $9,842,624,000,000
# 4                   South and South-East Asia (MPD)    $18,559,032,000,000
# 5                          Sub-Saharan Africa (MPD)     $3,701,549,600,000
# 6                              Western Europe (MPD)    $16,736,345,000,000
# 7                           Western offshoots (MPD)    $21,219,620,000,000

# %%
# Save the DataFrame to a CSV file
df.to_csv('Gross domestic product (GDP) by world region 2018', index=False)
