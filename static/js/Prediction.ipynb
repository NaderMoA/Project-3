# %%
import pandas as pd

# %%
df = pd.read_csv("lung-cancer-deaths-per-100000-by-sex-1950-2002.csv")

# %%
df.head()
# Out:
#     Entity Code  Year  age-standardized_death_rate_per_100k_male  \
# 0  Albania  ALB  1987                                      38.99
# 1  Albania  ALB  1988                                      41.27
# 2  Albania  ALB  1989                                      36.56
# 3  Albania  ALB  1992                                      29.70
# 4  Albania  ALB  1993                                      27.44
#
#    age-standardized_death_rate_per_100k_female
# 0                                         5.95
# 1                                         6.97
# 2                                         4.42
# 3                                         5.68
# 4                                         5.41

# %%
uk_df = df.loc[df['Entity'] == "United Kingdom"]

# %%
uk_df.head()
# Out:
#               Entity Code  Year  age-standardized_death_rate_per_100k_male  \
# 4279  United Kingdom  GBR  1950                                      40.79
# 4280  United Kingdom  GBR  1951                                      44.14
# 4281  United Kingdom  GBR  1952                                      47.08
# 4282  United Kingdom  GBR  1953                                      50.49
# 4283  United Kingdom  GBR  1954                                      53.96
#
#       age-standardized_death_rate_per_100k_female
# 4279                                         6.63
# 4280                                         6.72
# 4281                                         6.98
# 4282                                         7.11
# 4283                                         7.28

# %%
us_df = df.loc[df['Entity'] == "United States"]
us_df.head()
# Out:
#              Entity Code  Year  age-standardized_death_rate_per_100k_male  \
# 4349  United States  USA  1950                                      19.56
# 4350  United States  USA  1951                                      20.73
# 4351  United States  USA  1952                                      22.38
# 4352  United States  USA  1953                                      24.35
# 4353  United States  USA  1954                                      25.30
#
#       age-standardized_death_rate_per_100k_female
# 4349                                         4.34
# 4350                                         4.35
# 4351                                         4.52
# 4352                                         4.41
# 4353                                         4.43

# %%
argentina_df = df.loc[df['Entity'] == "Argentina"]
argentina_df.head()
# Out:
#        Entity Code  Year  age-standardized_death_rate_per_100k_male  \
# 67  Argentina  ARG  1966                                      44.43
# 68  Argentina  ARG  1967                                      50.98
# 69  Argentina  ARG  1968                                      52.27
# 70  Argentina  ARG  1969                                      52.59
# 71  Argentina  ARG  1970                                      52.60
#
#     age-standardized_death_rate_per_100k_female
# 67                                         5.67
# 68                                         6.15
# 69                                         7.43
# 70                                         7.06
# 71                                         6.64

# %%
spain_df = df.loc[df['Entity'] == "Spain"]
spain_df.head()
# Out:
#      Entity Code  Year  age-standardized_death_rate_per_100k_male  \
# 3773  Spain  ESP  1951                                       8.13
# 3774  Spain  ESP  1952                                       9.92
# 3775  Spain  ESP  1953                                      10.09
# 3776  Spain  ESP  1954                                      11.58
# 3777  Spain  ESP  1955                                      13.23
#
#       age-standardized_death_rate_per_100k_female
# 3773                                         2.45
# 3774                                         2.55
# 3775                                         2.59
# 3776                                         3.10
# 3777                                         3.07

# %%
# !python -m pip install prophet

# %%
# %pip install prophet

# %%
from prophet import Prophet

# %%
spain_prof_df = spain_df.rename(columns={'Year': 'ds', 'age-standardized_death_rate_per_100k_male': 'y'})

# %%
spain_prof_df["ds"].dtype
# Out:
# dtype('int64')

# %%
spain_prof_df['ds'] = pd.to_datetime(spain_prof_df['ds'], format="%Y")
# max_year = spain_prof_df['ds'].max().year
# start_year = max_year + 1
spain_prof_df.head()
# Out:
#      Entity Code         ds      y  \
# 3773  Spain  ESP 1951-01-01   8.13
# 3774  Spain  ESP 1952-01-01   9.92
# 3775  Spain  ESP 1953-01-01  10.09
# 3776  Spain  ESP 1954-01-01  11.58
# 3777  Spain  ESP 1955-01-01  13.23
#
#       age-standardized_death_rate_per_100k_female
# 3773                                         2.45
# 3774                                         2.55
# 3775                                         2.59
# 3776                                         3.10
# 3777                                         3.07

# %%
spain_prof_df.head()
# Out:
#      Entity Code                            ds      y  \
# 3773  Spain  ESP 1970-01-01 00:00:00.000001951   8.13
# 3774  Spain  ESP 1970-01-01 00:00:00.000001952   9.92
# 3775  Spain  ESP 1970-01-01 00:00:00.000001953  10.09
# 3776  Spain  ESP 1970-01-01 00:00:00.000001954  11.58
# 3777  Spain  ESP 1970-01-01 00:00:00.000001955  13.23
#
#       age-standardized_death_rate_per_100k_female
# 3773                                         2.45
# 3774                                         2.55
# 3775                                         2.59
# 3776                                         3.10
# 3777                                         3.07

# %%
model = Prophet()
model.fit(spain_prof_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbb2u0mkp/o1xzcq23.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbb2u0mkp/xfzyalr7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99623', 'data', 'file=/tmp/tmpbb2u0mkp/o1xzcq23.json', 'init=/tmp/tmpbb2u0mkp/xfzyalr7.json', 'output', 'file=/tmp/tmpbb2u0mkp/prophet_modelzygx4pdv/prophet_model-20240416010705.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 01:07:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 01:07:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
spain_future = model.make_future_dataframe(periods=15,freq='YS')

forecast = model.predict(spain_future)

# %%
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(20))
# Out:
#            ds       yhat  yhat_lower  yhat_upper
# 65 2016-01-01  40.755033   39.941114   41.626683
# 66 2017-01-01  39.766420   38.901352   40.646038
# 67 2018-01-01  38.917580   38.069162   39.804381
# 68 2019-01-01  38.019891   37.147567   38.914085
# 69 2020-01-01  37.072820   36.202310   37.929902
# 70 2021-01-01  36.084207   35.228122   36.930868
# 71 2022-01-01  35.235368   34.343842   36.117666
# 72 2023-01-01  34.337678   33.418784   35.274058
# 73 2024-01-01  33.390608   32.317482   34.401039
# 74 2025-01-01  32.401995   31.253419   33.581119
# 75 2026-01-01  31.553155   30.247366   32.938760
# 76 2027-01-01  30.655466   29.182779   32.086037
# 77 2028-01-01  29.708396   28.062889   31.350538
# 78 2029-01-01  28.719783   26.807334   30.575590
# 79 2030-01-01  27.870943   25.879112   30.093714
# 80 2031-01-01  26.973254   24.641412   29.394386
# 81 2032-01-01  26.026183   23.214434   28.619110
# 82 2033-01-01  25.037570   21.978741   28.213101
# ...
